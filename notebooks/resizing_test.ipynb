# %%
from PIL import Image
import matplotlib.pyplot as plt
import os

sample_image_path = os.path.join('../FERPlusData/FER2013Train', 'fer0000000.png')

# Load the image in grayscale mode
img = Image.open(sample_image_path).convert('L')

# Resize the image from 48x48 to 96x96 using Lanczos interpolation (best for upscaling)
resized_img = img.resize((96, 96), Image.LANCZOS)

# Display the original and resized images side by side
fig, axes = plt.subplots(1, 2, figsize=(8, 4))
axes[0].imshow(img, cmap='gray')
axes[0].set_title('Original Image (48x48)')
axes[0].axis('off')

axes[1].imshow(resized_img, cmap='gray')
axes[1].set_title('Resized Image (96x96)')
axes[1].axis('off')

plt.show()
